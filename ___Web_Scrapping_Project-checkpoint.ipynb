# %% [markdown]
# # 1. Scrape books.toscrape Website

# %% [markdown]
# In this web scraping project, two websites were scraped using the BeautifulSoup library in Python. The first website is "books.toscrape.com" and the second website is Wikipedia.
#
# For the first website, the objective was to scrape book titles, prices, and the availability of books in stock. The data was extracted using BeautifulSoup and stored in a pandas dataframe for further analysis. The dataframe consists of columns for Book Titles, Price, and Instock Availability. The purpose of this analysis was to identify the most popular books based on their price.
#
# The second website, Wikipedia, was scraped to collect country data from a table. The specific table contained information about the population of various countries. Similar to the book scraping, BeautifulSoup was used to extract the data and create a pandas dataframe. The dataframe columns include Country, Population, % of World, Date, and United Nations. The objective was to perform an analysis on the dataset and find the top 10 biggest and smallest countries based on their population.
#
# Furthermore, the project involved scraping another Wikipedia page titled "List of largest companies by revenue". The table on this page provides information about the revenue, profit, number of employees, and headquarters of the largest companies. The data was extracted and organized into a pandas dataframe. The dataframe columns include Name, Industry, Revenue, Profit, Employees, Headquarters, and State-owned. The goal of this part of the project was to collect and analyze information regarding the largest companies by revenue.
#
# Overall, the project involved scraping data from multiple sources, including book details, country population, and information about large companies. The extracted data was transformed into pandas dataframes for further analysis and insights.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import requests
from bs4 import BeautifulSoup

# Fetch the webpage
url = 'https://books.toscrape.com/catalogue/page-3.html'
response = requests.get(url)

# Create BeautifulSoup object
soup = BeautifulSoup(response.text, 'html.parser')

# Find all <h3> tags within <article> tags
articles = soup.find_all('article', class_="product_pod")
h3_texts = [h3.text for article in articles for h3 in article.find_all('h3')]

print(h3_texts)
# Out:
# ['Slow States of Collapse: ...', 'Reasons to Stay Alive', 'Private Paris (Private #10)', '#HigherSelfie: Wake Up Your ...', 'Without Borders (Wanderlove #1)', 'When We Collided', 'We Love You, Charlie ...', 'Untitled Collection: Sabbath Poems ...', 'Unseen City: The Majesty ...', 'Unicorn Tracks', 'Unbound: How Eight Technologies ...', 'Tsubasa: WoRLD CHRoNiCLE 2 ...', 'Throwing Rocks at the ...', 'This One Summer', 'Thirst', 'The Torch Is Passed: ...', 'The Secret of Dreadwillow ...', 'The Pioneer Woman Cooks: ...', 'The Past Never Ends', 'The Natural History of ...']

# %% [markdown]
# ## Insights
# - There is a problem, whole title of books are hidden

# %%
import requests
from bs4 import BeautifulSoup

# Fetch the webpage
url = 'https://books.toscrape.com/catalogue/page-3.html'
response = requests.get(url)

# Create BeautifulSoup object
soup = BeautifulSoup(response.text, 'html.parser')

a = soup.find_all('article', class_="product_pod")
print(a)
# Out:
# [<article class="product_pod">
# <div class="image_container">
# <a href="slow-states-of-collapse-poems_960/index.html"><img alt="Slow States of Collapse: Poems" class="thumbnail" src="../media/cache/72/41/72417db983862010ef0c1a25de98c7d7.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="slow-states-of-collapse-poems_960/index.html" title="Slow States of Collapse: Poems">Slow States of Collapse: ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£57.31</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>, <article class="product_pod">
# <div class="image_container">
# ...

# %% [markdown]
# ## Use another approach to find out whole book titles

# %%
# Fetch the webpage
url = 'https://books.toscrape.com/catalogue/page-3.html'
response = requests.get(url)

# Create BeautifulSoup object
soup = BeautifulSoup(response.text, 'html.parser')

# Find all article elements with class "product_pod"
articles = soup.find_all('article', class_="product_pod")

# Iterate over each article and extract the href value
for article in articles:
    href = article.find('a')['href']
    print(href)
# Out:
# slow-states-of-collapse-poems_960/index.html
# reasons-to-stay-alive_959/index.html
# private-paris-private-10_958/index.html
# higherselfie-wake-up-your-life-free-your-soul-find-your-tribe_957/index.html
# without-borders-wanderlove-1_956/index.html
# when-we-collided_955/index.html
# we-love-you-charlie-freeman_954/index.html
# untitled-collection-sabbath-poems-2014_953/index.html
# unseen-city-the-majesty-of-pigeons-the-discreet-charm-of-snails-other-wonders-of-the-urban-wilderness_952/index.html
# unicorn-tracks_951/index.html
# unbound-how-eight-technologies-made-us-human-transformed-society-and-brought-our-world-to-the-brink_950/index.html
# tsubasa-world-chronicle-2-tsubasa-world-chronicle-2_949/index.html
# throwing-rocks-at-the-google-bus-how-growth-became-the-enemy-of-prosperity_948/index.html
# this-one-summer_947/index.html
# thirst_946/index.html
# the-torch-is-passed-a-harding-family-story_945/index.html
# the-secret-of-dreadwillow-carse_944/index.html
# ...

# %%
import requests
from bs4 import BeautifulSoup

base_url = 'https://books.toscrape.com/catalogue/page-{}.html'

# Perform pagination and extract href values
for page in range(1, 51):
    url = base_url.format(page)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all article elements with class "product_pod"
    articles = soup.find_all('article', class_="product_pod")

    # Iterate over each article and extract the href value
    for article in articles:
        href = article.find('a')['href']
        print(href)
# Out:
# a-light-in-the-attic_1000/index.html
# tipping-the-velvet_999/index.html
# soumission_998/index.html
# sharp-objects_997/index.html
# sapiens-a-brief-history-of-humankind_996/index.html
# the-requiem-red_995/index.html
# the-dirty-little-secrets-of-getting-your-dream-job_994/index.html
# the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html
# the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html
# the-black-maria_991/index.html
# starving-hearts-triangular-trade-trilogy-1_990/index.html
# shakespeares-sonnets_989/index.html
# set-me-free_988/index.html
# scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html
# rip-it-up-and-start-again_986/index.html
# our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html
# olio_984/index.html
# mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html
# ...

# %%
import requests
from bs4 import BeautifulSoup

base_url = 'https://books.toscrape.com/catalogue/page-{}'

# Create an empty list for href_urls
href_urls = []

# Perform pagination and extract href values
for page in range(1, 51):
    url = base_url.format(page) + '.html'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all article elements with class "product_pod"
    articles = soup.find_all('article', class_="product_pod")

    # Iterate over each article and extract the href value
    for article in articles:
        href = article.find('a')['href']
        href_urls.append(href)

# %%
len(href_urls)
# Out:
# 1000

# %%
href_urls
# Out:
# ['a-light-in-the-attic_1000/index.html',
#  'tipping-the-velvet_999/index.html',
#  'soumission_998/index.html',
#  'sharp-objects_997/index.html',
#  'sapiens-a-brief-history-of-humankind_996/index.html',
#  'the-requiem-red_995/index.html',
#  'the-dirty-little-secrets-of-getting-your-dream-job_994/index.html',
#  'the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html',
#  'the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html',
#  'the-black-maria_991/index.html',
#  'starving-hearts-triangular-trade-trilogy-1_990/index.html',
#  'shakespeares-sonnets_989/index.html',
#  'set-me-free_988/index.html',
#  'scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html',
#  'rip-it-up-and-start-again_986/index.html',
#  'our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html',
#  'olio_984/index.html',
# ...

# %%
c

# %%
new_urls
# Out:
# ['https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html',
#  'https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html',
#  'https://books.toscrape.com/catalogue/soumission_998/index.html',
#  'https://books.toscrape.com/catalogue/sharp-objects_997/index.html',
#  'https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html',
#  'https://books.toscrape.com/catalogue/the-requiem-red_995/index.html',
#  'https://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html',
#  'https://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html',
#  'https://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html',
#  'https://books.toscrape.com/catalogue/the-black-maria_991/index.html',
# ...

# %%
len(new_urls)
# Out:
# 1000

# %%
c
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     The Natural History of Us (The Fine Art of Pretending #2) | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:30" name="created"/>
# <meta content="
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Fetch the webpage
url = 'https://books.toscrape.com/catalogue/the-natural-history-of-us-the-fine-art-of-pretending-2_941/index.html'
response = requests.get(url)

# Create BeautifulSoup object
soup = BeautifulSoup(response.text, 'html.parser')

# Find the h1 element with the specified title
title_element = soup.find('h1', text='The Natural History of Us (The Fine Art of Pretending #2)')

# Print the h1 element
print(title_element)
# Out:
# <h1>The Natural History of Us (The Fine Art of Pretending #2)</h1>

# %%
import requests
from bs4 import BeautifulSoup



for url in new_urls:
    # Fetch the webpage
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the h1 tag
    h1_tag = soup.find('h1')

    # Print the text of the h1 tag
    print(h1_tag.text)
# Out:
# A Light in the Attic
# Tipping the Velvet
# Soumission
# Sharp Objects
# Sapiens: A Brief History of Humankind
# The Requiem Red
# The Dirty Little Secrets of Getting Your Dream Job
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# The Black Maria
# Starving Hearts (Triangular Trade Trilogy, #1)
# Shakespeare's Sonnets
# Set Me Free
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# Rip it Up and Start Again
# Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
# Olio
# Mesaerion: The Best Science Fiction Stories 1800-1849
# Libertarianism for Beginners
# It's Only the Himalayas
# In Her Wake
# How Music Works
# Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More
# ...

# %%
new_urls
# Out:
# ['https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html',
#  'https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html',
#  'https://books.toscrape.com/catalogue/soumission_998/index.html',
#  'https://books.toscrape.com/catalogue/sharp-objects_997/index.html',
#  'https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html',
#  'https://books.toscrape.com/catalogue/the-requiem-red_995/index.html',
#  'https://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html',
#  'https://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html',
#  'https://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html',
#  'https://books.toscrape.com/catalogue/the-black-maria_991/index.html',
# ...

# %%
import requests
from bs4 import BeautifulSoup

book_titles = []

for url in new_urls:
    # Fetch the webpage
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the h1 tag
    h1_tag = soup.find('h1')

    # Append the text of the h1 tag to book_titles list
    book_titles.append(h1_tag.text)

# %%
book_titles
# Out:
# ['A Light in the Attic',
#  'Tipping the Velvet',
#  'Soumission',
#  'Sharp Objects',
#  'Sapiens: A Brief History of Humankind',
#  'The Requiem Red',
#  'The Dirty Little Secrets of Getting Your Dream Job',
#  'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#  'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#  'The Black Maria',
#  'Starving Hearts (Triangular Trade Trilogy, #1)',
#  "Shakespeare's Sonnets",
#  'Set Me Free',
#  "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#  'Rip it Up and Start Again',
#  'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#  'Olio',
#  'Mesaerion: The Best Science Fiction Stories 1800-1849',
#  'Libertarianism for Beginners',
#  "It's Only the Himalayas",
#  'In Her Wake',
#  'How Music Works',
# ...

# %% [markdown]
# # To find out price of books

# %%
import requests
from bs4 import BeautifulSoup

# Send a GET request to the webpage
url = "https://books.toscrape.com/catalogue/page-50.html"
response = requests.get(url)

soup = BeautifulSoup(response.content, "html.parser")

# Find all <p> tags with the class "price_color"
price_tags = soup.find_all('p', class_="price_color")

# Extract and print the text from the price tags
for price_tag in price_tags:
    print(price_tag.text)
# Out:
# £38.00
# £28.80
# £39.24
# £32.93
# £51.32
# £47.09
# £28.42
# £22.85
# £41.24
# £39.07
# £29.82
# £37.26
# £20.30
# £34.65
# £43.38
# £55.53
# £57.06
# £16.97
# £53.98
# £26.08

# %%
import requests
from bs4 import BeautifulSoup

# Create an empty list to store the prices
price = []

# Loop through all the pages
for page_num in range(1, 51):
    # Send a GET request to each page
    url = f"https://books.toscrape.com/catalogue/page-{page_num}.html"
    response = requests.get(url)
    
    # Parse the HTML content
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Find all <p> tags with the class "price_color"
    price_tags = soup.find_all('p', class_="price_color")

    # Append the text from the price tags to the 'price' list
    for price_tag in price_tags:
        price.append(price_tag.text)

# Print the prices
for p in price:
    print(p)
# Out:
# £51.77
# £53.74
# £50.10
# £47.82
# £54.23
# £22.65
# £33.34
# £17.93
# £22.60
# £52.15
# £13.99
# £20.66
# £17.46
# £52.29
# £35.02
# £57.25
# £23.88
# £37.59
# £51.33
# £45.17
# £12.84
# £37.32
# £30.52
# £25.27
# £34.53
# £54.64
# £22.50
# £53.13
# £40.30
# £44.18
# £17.66
# £31.05
# £23.82
# £36.89
# £15.94
# £33.29
# £18.02
# £19.63
# £52.22
# £33.63
# £57.31
# £26.41
# £47.61
# £23.11
# £45.07
# £31.77
# £50.27
# £14.27
# £44.18
# £18.78
# £25.52
# £16.28
# £31.12
# £19.49
# £17.27
# £19.09
# £56.13
# £56.41
# £56.50
# £45.22
# £38.16
# £54.11
# £42.96
# £23.89
# £16.77
# £20.59
# £37.13
# £56.06
# £58.11
# £49.05
# £40.76
# £19.73
# £32.24
# £41.83
# £39.58
# £39.25
# £25.02
# £51.04
# £19.83
# £50.40
# £13.61
# £13.34
# £18.97
# £36.28
# £10.16
# £15.44
# £48.41
# £46.35
# £14.07
# £14.86
# £33.37
# £56.40
# £14.02
# £46.91
# £45.61
# £19.92
# £40.11
# £53.90
# £35.67
# £22.00
# £57.36
# £29.17
# £54.63
# £46.03
# £33.97
# £22.11
# £29.69
# £15.97
# £21.96
# £54.35
# £37.97
# ...

# %% [markdown]
# ## To find out instock availability

# %%
import requests
from bs4 import BeautifulSoup

# Send a GET request to the webpage
url = "https://books.toscrape.com/catalogue/page-50.html"
response = requests.get(url)

soup = BeautifulSoup(response.content, "html.parser")

# Find all <p> tags with the class "price_color"
stock_availability = soup.find_all('p', class_="instock availability")

# Extract and print the text from the price tags
for stock in stock_availability:
    print(stock.text.strip())
# Out:
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock

# %%
import requests
from bs4 import BeautifulSoup

# Create an empty list to store the stock availability
instock_availability = []

# Loop through all the pages
for page_num in range(1, 51):
    # Send a GET request to each page
    url = f"https://books.toscrape.com/catalogue/page-{page_num}.html"
    response = requests.get(url)

    # Parse the HTML content
    soup = BeautifulSoup(response.content, "html.parser")

    # Find all <p> tags with the class "instock availability"
    stock_availability = soup.find_all('p', class_="instock availability")

    # Append the text from the stock availability tags to the 'instock_availability' list
    for stock in stock_availability:
        instock_availability.append(stock.text.strip())

# Print the stock availability
for stock in instock_availability:
    print(stock)
# Out:
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# In stock
# ...

# %%
book_titles
# Out:
# ['A Light in the Attic',
#  'Tipping the Velvet',
#  'Soumission',
#  'Sharp Objects',
#  'Sapiens: A Brief History of Humankind',
#  'The Requiem Red',
#  'The Dirty Little Secrets of Getting Your Dream Job',
#  'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#  'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#  'The Black Maria',
#  'Starving Hearts (Triangular Trade Trilogy, #1)',
#  "Shakespeare's Sonnets",
#  'Set Me Free',
#  "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#  'Rip it Up and Start Again',
#  'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#  'Olio',
#  'Mesaerion: The Best Science Fiction Stories 1800-1849',
#  'Libertarianism for Beginners',
#  "It's Only the Himalayas",
#  'In Her Wake',
#  'How Music Works',
# ...

# %%
price
# Out:
# ['£51.77',
#  '£53.74',
#  '£50.10',
#  '£47.82',
#  '£54.23',
#  '£22.65',
#  '£33.34',
#  '£17.93',
#  '£22.60',
#  '£52.15',
#  '£13.99',
#  '£20.66',
#  '£17.46',
#  '£52.29',
#  '£35.02',
#  '£57.25',
#  '£23.88',
#  '£37.59',
#  '£51.33',
#  '£45.17',
#  '£12.84',
#  '£37.32',
#  '£30.52',
#  '£25.27',
#  '£34.53',
#  '£54.64',
#  '£22.50',
#  '£53.13',
#  '£40.30',
#  '£44.18',
#  '£17.66',
#  '£31.05',
#  '£23.82',
#  '£36.89',
#  '£15.94',
#  '£33.29',
#  '£18.02',
#  '£19.63',
#  '£52.22',
#  '£33.63',
#  '£57.31',
#  '£26.41',
#  '£47.61',
#  '£23.11',
#  '£45.07',
#  '£31.77',
#  '£50.27',
#  '£14.27',
#  '£44.18',
#  '£18.78',
#  '£25.52',
#  '£16.28',
#  '£31.12',
#  '£19.49',
#  '£17.27',
#  '£19.09',
#  '£56.13',
#  '£56.41',
#  '£56.50',
#  '£45.22',
#  '£38.16',
#  '£54.11',
#  '£42.96',
#  '£23.89',
#  '£16.77',
#  '£20.59',
#  '£37.13',
#  '£56.06',
#  '£58.11',
#  '£49.05',
#  '£40.76',
#  '£19.73',
#  '£32.24',
#  '£41.83',
#  '£39.58',
#  '£39.25',
# ...

# %%
instock_availability
# Out:
# ['In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
# ...

# %%
len(book_titles)
# Out:
# 1000

# %%
len(price)
# Out:
# 1000

# %%
len(instock_availability)
# Out:
# 1000

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Book-Titles': book_titles, 'Price': price, 'Instock_Availability': instock_availability})

# %%
pd.set_option('display.max_colwidth', None)  # Unlimited column width display
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)  # Display all rows

# %%
# df.head()

# %%
# df.tail()

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.isnull().sum()
# Out:
# Book-Titles             0
# Price                   0
# Instock_Availability    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Book-Titles           1000 non-null   object
#  1   Price                 1000 non-null   object
#  2   Instock_Availability  1000 non-null   object
# dtypes: object(3)
# memory usage: 23.6+ KB

# %%
df['Price'] = df['Price'].str.replace('£', '')

# %%
df['Price']
# Out:
# 0      51.77
# 1      53.74
# 2      50.10
# 3      47.82
# 4      54.23
# 5      22.65
# 6      33.34
# 7      17.93
# 8      22.60
# 9      52.15
# 10     13.99
# 11     20.66
# 12     17.46
# 13     52.29
# 14     35.02
# 15     57.25
# 16     23.88
# 17     37.59
# 18     51.33
# 19     45.17
# 20     12.84
# 21     37.32
# 22     30.52
# 23     25.27
# 24     34.53
# 25     54.64
# 26     22.50
# 27     53.13
# 28     40.30
# 29     44.18
# 30     17.66
# 31     31.05
# 32     23.82
# 33     36.89
# 34     15.94
# 35     33.29
# 36     18.02
# 37     19.63
# 38     52.22
# 39     33.63
# 40     57.31
# 41     26.41
# 42     47.61
# 43     23.11
# 44     45.07
# 45     31.77
# 46     50.27
# 47     14.27
# 48     44.18
# 49     18.78
# 50     25.52
# 51     16.28
# 52     31.12
# 53     19.49
# 54     17.27
# 55     19.09
# 56     56.13
# 57     56.41
# 58     56.50
# 59     45.22
# 60     38.16
# 61     54.11
# 62     42.96
# 63     23.89
# 64     16.77
# 65     20.59
# ...

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce').astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Book-Titles           1000 non-null   object
#  1   Price                 1000 non-null   int32
#  2   Instock_Availability  1000 non-null   object
# dtypes: int32(1), object(2)
# memory usage: 19.7+ KB

# %%
df.describe()
# Out:
#              Price
# count  1000.000000
# mean     34.576000
# std      14.447732
# min      10.000000
# 25%      22.000000
# 50%      35.500000
# 75%      47.000000
# max      59.000000

# %% [markdown]
# ## Find out the top 10 books based on price

# %%
sorted_books = df.sort_values(by='Price', ascending=False)
top_10_books = sorted_books.head(10)

top_10_books = top_10_books.style.set_properties(**{'text-align': 'left'})
top_10_books = top_10_books.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])

top_10_books
# Out:
# <style type="text/css">
# #T_c8e4b th {
#   text-align: left;
# }
# #T_c8e4b_row0_col0, #T_c8e4b_row0_col1, #T_c8e4b_row0_col2, #T_c8e4b_row1_col0, #T_c8e4b_row1_col1, #T_c8e4b_row1_col2, #T_c8e4b_row2_col0, #T_c8e4b_row2_col1, #T_c8e4b_row2_col2, #T_c8e4b_row3_col0, #T_c8e4b_row3_col1, #T_c8e4b_row3_col2, #T_c8e4b_row4_col0, #T_c8e4b_row4_col1, #T_c8e4b_row4_col2, #T_c8e4b_row5_col0, #T_c8e4b_row5_col1, #T_c8e4b_row5_col2, #T_c8e4b_row6_col0, #T_c8e4b_row6_col1, #T_c8e4b_row6_col2, #T_c8e4b_row7_col0, #T_c8e4b_row7_col1, #T_c8e4b_row7_col2, #T_c8e4b_row8_col0, #T_c8e4b_row8_col1, #T_c8e4b_row8_col2, #T_c8e4b_row9_col0, #T_c8e4b_row9_col1, #T_c8e4b_row9_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_c8e4b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8e4b_level0_col0" class="col_heading level0 col0" >Book-Titles</th>
#       <th id="T_c8e4b_level0_col1" class="col_heading level0 col1" >Price</th>
# ...

# %%
import matplotlib.pyplot as plt

sorted_df = df.sort_values(by='Price', ascending=False)
top_10_records = sorted_df.head(10)

x = ['Top ' + str(i+1) for i in range(10)]
y = top_10_records['Price']

plt.bar(x, y)
plt.xlabel('Top Books')
plt.ylabel('Price')
plt.title('Top 10 Books by Price')
plt.show()

# %% [markdown]
# # 2. Scrape wikipidea table using beautiful soup

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

table = soup.find('table', {'class': 'wikitable sortable'})
data = []

rows = table.find_all('tr')
for row in rows:
    cells = row.find_all('td')
    if cells:
        row_data = []
        for cell in cells:
            row_data.append(cell.text.strip())
        data.append(row_data)

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                0              1      2            3  \
# 0          World  8,065,801,000   100%  15 Oct 2023
# 1          China  1,411,750,000  17.5%  31 Dec 2022
# 2          India  1,392,329,000  17.3%   1 Mar 2023
# 3  United States    335,514,000   4.2%  15 Oct 2023
# 4      Indonesia    278,696,200   3.5%   1 Jul 2023
#
#                                4    5
# 0               UN projection[3]
# 1           Official estimate[4]  [b]
# 2         Official projection[5]  [c]
# 3   National population clock[7]  [d]
# 4  National annual projection[8]

# %%
df = df.drop(5, axis=1)

# %%
df.head(1)
# Out:
#        0              1     2            3                 4
# 0  World  8,065,801,000  100%  15 Oct 2023  UN projection[3]

# %%
df.columns = ['Country', 'Population', '% of World','Date','United Nations']

# %%
df.head(1)
# Out:
#   Country     Population % of World         Date    United Nations
# 0   World  8,065,801,000       100%  15 Oct 2023  UN projection[3]

# %%
df.head()
# Out:
#          Country     Population % of World         Date  \
# 0          World  8,065,801,000       100%  15 Oct 2023
# 1          China  1,411,750,000      17.5%  31 Dec 2022
# 2          India  1,392,329,000      17.3%   1 Mar 2023
# 3  United States    335,514,000       4.2%  15 Oct 2023
# 4      Indonesia    278,696,200       3.5%   1 Jul 2023
#
#                   United Nations
# 0               UN projection[3]
# 1           Official estimate[4]
# 2         Official projection[5]
# 3   National population clock[7]
# 4  National annual projection[8]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         242 non-null    object
#  1   Population      242 non-null    object
#  2   % of World      242 non-null    object
#  3   Date            242 non-null    object
#  4   United Nations  242 non-null    object
# dtypes: object(5)
# memory usage: 9.6+ KB

# %%
df['% of World'] = df['% of World'].str.replace('%', '')
df['% of World']
# Out:
# 0       100
# 1      17.5
# 2      17.3
# 3       4.2
# 4       3.5
#        ...
# 237       0
# 238       0
# 239       0
# 240       0
# 241       0
# Name: % of World, Length: 242, dtype: object

# %%
df['Population'] = df['Population'].astype('int64')
df['% of World'] = df['% of World'].astype(float)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head(1)
# Out:
#   Country  Population  % of World       Date    United Nations
# 0   World  8065801000       100.0 2023-10-15  UN projection[3]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         242 non-null    object
#  1   Population      242 non-null    int64
#  2   % of World      242 non-null    float64
#  3   Date            242 non-null    datetime64[ns]
#  4   United Nations  242 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 9.6+ KB

# %%
df.head()
# Out:
#          Country  Population  % of World       Date  \
# 0          World  8065801000       100.0 2023-10-15
# 1          China  1411750000        17.5 2022-12-31
# 2          India  1392329000        17.3 2023-03-01
# 3  United States   335514000         4.2 2023-10-15
# 4      Indonesia   278696200         3.5 2023-07-01
#
#                   United Nations
# 0               UN projection[3]
# 1           Official estimate[4]
# 2         Official projection[5]
# 3   National population clock[7]
# 4  National annual projection[8]

# %%
df.shape
# Out:
# (242, 5)

# %%
df_sorted = df.sort_values(by='Population', ascending=False)

# %%
df_sorted.head()
# Out:
#          Country  Population  % of World       Date  \
# 0          World  8065801000       100.0 2023-10-15
# 1          China  1411750000        17.5 2022-12-31
# 2          India  1392329000        17.3 2023-03-01
# 3  United States   335514000         4.2 2023-10-15
# 4      Indonesia   278696200         3.5 2023-07-01
#
#                   United Nations
# 0               UN projection[3]
# 1           Official estimate[4]
# 2         Official projection[5]
# 3   National population clock[7]
# 4  National annual projection[8]

# %%
ten_biggest_country = df_sorted.iloc[1:11] 
ten_biggest_country
# Out:
#           Country  Population  % of World       Date  \
# 1           China  1411750000        17.5 2022-12-31
# 2           India  1392329000        17.3 2023-03-01
# 3   United States   335514000         4.2 2023-10-15
# 4       Indonesia   278696200         3.5 2023-07-01
# 5        Pakistan   241499431         3.0 2023-03-01
# 6         Nigeria   216783400         2.7 2022-03-21
# 7          Brazil   203062512         2.5 2022-08-01
# 8      Bangladesh   169828911         2.1 2022-06-14
# 9          Russia   146424729         1.8 2023-01-01
# 10         Mexico   129202482         1.6 2023-06-30
#
#                      United Nations
# 1              Official estimate[4]
# 2            Official projection[5]
# 3      National population clock[7]
# 4     National annual projection[8]
# 5             2023 census result[9]
# 6           Official projection[10]
# 7            2022 census result[11]
# 8            2022 census result[12]
# 9             Official estimate[13]
# ...

# %%
import matplotlib.pyplot as plt

plt.barh(ten_biggest_country['Country'], ten_biggest_country['Population'])
plt.xlabel('Population')
plt.ylabel('Country')
plt.title('10 Biggest Countries in the World Based on Population')
plt.show()

# %%
df_sorted = df.sort_values(by='Population', ascending=True)

# %%
ten_smallest_country = df_sorted.head(10)

# %%
ten_smallest_country
# Out:
#                                                Country  Population  \
# 241                              Pitcairn Islands (UK)          47
# 240                Cocos (Keeling) Islands (Australia)         593
# 239                                       Vatican City         764
# 238                                               Niue        1549
# 237                                       Tokelau (NZ)        1647
# 236                       Christmas Island (Australia)        1692
# 235                         Norfolk Island (Australia)        2188
# 234                              Falkland Islands (UK)        3662
# 233                                    Montserrat (UK)        4433
# 232  Saint Helena, Ascension and Tristan da Cunha (UK)        5651
#
#      % of World       Date                   United Nations
# 241         0.0 2021-07-01           Official estimate[233]
# 240         0.0 2020-06-30                 2021 Census[232]
# ...

# %%
import matplotlib.pyplot as plt

plt.barh(ten_smallest_country['Country'], ten_smallest_country['Population'])
plt.xlabel('Population')
plt.ylabel('Country')
plt.title('10 Smallest Countries in the World Based on Population')
plt.show()

# %% [markdown]
# # 3. Scrape Wikipedia Table Using Pandas

# %%
import pandas as pd

url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue'
tables = pd.read_html(url)

# Print the number of tables found
print(f"Number of tables: {len(tables)}")

# Access the desired table
table_index = 0  # Change this value if the desired table is different
desired_table = tables[table_index]
# Out:
# Number of tables: 5

# %%
import pandas as pd

url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue'
tables = pd.read_html(url)

# Access the first table
desired_table = tables[0]

# %%
desired_table
# Out:
#    Rank                                     Name                Industry  \
#    Rank                                     Name                Industry
# 0     1                                  Walmart                  Retail
# 1     2                             Saudi Aramco             Oil and gas
# 2     3          State Grid Corporation of China             Electricity
# 3     4                                   Amazon                  Retail
# 4     5                                    Vitol             Commodities
# 5     6     China National Petroleum Corporation             Oil and gas
# 6     7          China Petrochemical Corporation             Oil and gas
# 7     8                               ExxonMobil             Oil and gas
# 8     9                                    Apple             Electronics
# 9    10                                    Shell             Oil and gas
# 10   11                       UnitedHealth Group              Healthcare
# ...
